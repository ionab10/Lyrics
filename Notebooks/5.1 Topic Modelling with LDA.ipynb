# %%
import pandas as pd
import random
from gensim import corpora
from gensim.parsing.preprocessing import preprocess_string, strip_tags, strip_punctuation, strip_multiple_whitespaces, strip_numeric, remove_stopwords, strip_short
from gensim.models.ldamodel import LdaModel
from collections import Counter

# %%
song_df=pd.read_csv("../Data/songdata_clean.csv",sep=',', encoding='utf-8', usecols=['artist','song','lyrics'])
song_df.dropna(inplace=True)
print(len(song_df))
song_df.head()
# Out:
# 56148
#   artist                   song  \
# 0   ABBA  She's My Kind Of Girl
# 1   ABBA       Andante, Andante
# 2   ABBA         As Good As New
# 3   ABBA                   Bang
# 4   ABBA       Bang-A-Boomerang
#
#                                               lyrics
# 0  Look at her face, it's a wonderful face  \r\r\...
# 1  Take it easy with me, please  \r\r\r\r\r\r\r\r...
# 2  I'll never know why I had to go  \r\r\r\r\r\r\...
# 3  Making somebody happy is a question of give an...
# 4  Making somebody happy is a question of give an...

# %% [markdown]
# # Latent-Dirichlet Allocation (LDA)
# LDA is common topic modelling technique that embed word-counts and document term matrices to identify a specified number of topics in a corpus. This notebook implements LDA for the lyrics dataset.

# %% [markdown]
# ## Clean documents
# Lyrics are different than novels. Slang and the particular way an artist writes or sings is important. Because of this we will not stem (keeping only the root of the word) the words in our corpus.

# %%
CUSTOM_FILTERS = [lambda x: x.lower(), strip_tags, strip_punctuation, strip_multiple_whitespaces, strip_numeric, remove_stopwords, strip_short]
doc_clean = [preprocess_string(doc, filters=CUSTOM_FILTERS) for doc in song_df.lyrics]

# %% [markdown]
# ## Create document term matrix

# %%
dictionary = corpora.Dictionary(doc_clean)
# %time doc_term_matrix = [dictionary.doc2bow(doc) for doc in doc_clean]
song_df['bow']=doc_term_matrix
# Out:
# Wall time: 2.81 s

# %% [markdown]
# ## Create Training set
# LDA takes a while to run so we will train on a random subset of the data.

# %%
train_corpus=random.sample(doc_clean,1000)
#train_corpus=doc_clean

# %% [markdown]
# ## Train LDA model
# We will assume 20 possible topics across the dataset (num_topics=20).

# %%
# %time ldamodel = LdaModel(doc_term_matrix, num_topics=20, id2word = dictionary, passes=50)
# Out:
# Wall time: 1h 8min 8s

# %%
ldamodel.save('../Data/lda.model')

# %% [markdown]
# # Topic Modelling

# %%
ldamodel=LdaModel.load('../Data/lda.model')

# %%
topics=ldamodel.top_topics(doc_term_matrix, topn=6)
#topn is the number of words used to describe a topic
[(i,[x[1] for x in t[0]]) for i,t in enumerate(topics)]
# Out:
# [(0, ['know', 'time', 'way', 'life', 'away', 'feel']),
#  (1, ['nigga', 'like', 'ain', 'cause', 'shit', 'fuck']),
#  (2, ['baby', 'know', 'gonna', 'girl', 'got', 'wanna']),
#  (3, ['love', 'heart', 'need', 'hold', 'like', 'forever']),
#  (4, ['said', 'old', 'man', 'got', 'new', 'boy']),
#  (5, ['sun', 'sky', 'rain', 'blue', 'like', 'run']),
#  (6, ['night', 'eyes', 'home', 'long', 'gone', 'dream']),
#  (7, ['let', 'come', 'tonight', 'night', 'dance', 'everybody']),
#  (8, ['like', 'look', 'going', 'people', 'better', 'round']),
#  (9, ['god', 'lord', 'sing', 'heaven', 'song', 'jesus']),
#  (10, ['got', 'bitch', 'rock', 'roll', 'ready', 'ride']),
#  (11, ['yeah', 'hey', 'gotta', 'whoa', 'alright', 'stop']),
#  (12, ['die', 'hell', 'blood', 'death', 'war', 'wit']),
#  (13, ['bad', 'somebody', 'wish', 'yes', 'dead', 'save']),
#  (14, ['happy', 'christmas', 'bring', 'bye', 'days', 'year']),
#  (15, ['little', 'bit', 'miss', 'sister', 'wait', 'piece']),
#  (16, ['ooh', 'mama', 'beautiful', 'blues', 'doo', 'chicken']),
#  (17, ['man', 'gimme', 'gun', 'hand', 'marching', 'weed']),
#  (18, ['want', 'woman', 'motherfucker', 'sick', 'candy', 'pum']),
#  (19, ['boom', 'paradise', 'ang', 'maria', 'est', 'japan'])]

# %% [markdown]
# From each set of topic words, we can identify a theme.

# %% [markdown]
# ## Get topics for each song

# %%
def get_topic(doc, model):
    try:
        return sorted(model[doc], key=lambda x: x[1])[0][0]
    except:
        return None

# %% [markdown]
# For example, take a random song and identify the topic code. To see what the song is about, we then cross-reference this number with the topic words above.

# %%
i=random.randint(1, len(song_df))
print(song_df.lyrics[i])
get_topic(song_df.bow[i], ldamodel)
# Out:
# Dark night, there is no light
# In the realm of the black magic man
# Soul's flight into the cold blight
# Of the destroyer's magic land
#
# Poor man, whose spirits are stronger
# They're the ones who will reign
# You're struggles are in vain
#
# Blind man, you're suckin' your own blood
# Soon black magic's dying
# You'd better start crying
#
# Blind man, you're suckin' your own blood
# Soon black magic's dying
# You'd better start crying
#
# Throw out your evil desire
# The dark king's kingdom is
# Made out of mire
#
# Throw out your evil desire
# The dark king's kingdom is
# Made out of mire
#
# Keep on for the kingdom of light
# There is no darkness, there is no night
# 13

# %%
song_df['topic']=[[]]*len(song_df)

for i,doc in song_df.bow.iteritems():
    song_df.at[i,'topic']=get_topic(doc, ldamodel)
song_df.head()
# Out:
#   artist                   song  \
# 0   ABBA  She's My Kind Of Girl
# 1   ABBA       Andante, Andante
# 2   ABBA         As Good As New
# 3   ABBA                   Bang
# 4   ABBA       Bang-A-Boomerang
#
#                                               lyrics  \
# 0  Look at her face, it's a wonderful face  \r\r\...
# 1  Take it easy with me, please  \r\r\r\r\r\r\r\r...
# 2  I'll never know why I had to go  \r\r\r\r\r\r\...
# 3  Making somebody happy is a question of give an...
# 4  Making somebody happy is a question of give an...
#
#                                                  bow topic
# 0  [(0, 2), (1, 2), (2, 2), (3, 2), (4, 1), (5, 2...    15
# 1  [(28, 20), (29, 1), (30, 1), (31, 1), (32, 1),...    10
# 2  [(3, 1), (12, 1), (26, 2), (33, 2), (43, 2), (...     7
# 3  [(3, 1), (12, 1), (29, 2), (37, 1), (43, 1), (...     8
# 4  [(3, 1), (12, 1), (29, 2), (37, 1), (43, 1), (...     4

# %%
Counter(song_df.topic)
# Out:
# Counter({0: 4804,
#          1: 2837,
#          2: 2824,
#          3: 5621,
#          4: 1305,
#          5: 1862,
#          6: 1348,
#          7: 3138,
#          8: 615,
#          9: 2521,
#          10: 2130,
#          11: 1988,
#          12: 2542,
#          13: 3017,
#          14: 1586,
#          15: 4017,
#          16: 4194,
#          17: 4609,
#          18: 1632,
#          19: 3558})

# %% [markdown]
# Let us take a look as songs about topic 3:

# %%
song_df.query('topic=={}'.format(3)).loc[:,['artist','song','lyrics']]
# Out:
#                  artist                              song  \
# 6                  ABBA                         Cassandra
# 31                 ABBA                     Hey Hey Helen
# 63                 ABBA                           Move On
# 73                 ABBA        Put On Your White Sombrero
# 92                 ABBA                         That's Me
# 122         Ace Of Base         Never Gonna Say I'm Sorry
# 135               Adele                     Crazy For You
# 136               Adele                        Daydreamer
# 139               Adele            Melt My Heart To Stone
# 156           Aerosmith                       Lay It Down
# 163           Aerosmith                          Mama Kin
# 171           Aerosmith                           My Girl
# 177           Aerosmith                 On The Road Again
# 186           Aerosmith                          Rag Doll
# 194           Aerosmith                   Round And Round
# 203           Aerosmith               Sight For Sore Eyes
# 237          Air Supply                         After All
# 240          Air Supply                   All Out Of Love
# 263          Air Supply                Don't Turn Me Away
# 264          Air Supply                   Don't Walk Away
# 265          Air Supply                       Empty Pages
# 268          Air Supply          Every Woman In The World
# 272          Air Supply                Hard To Forget Her
# 282          Air Supply           I Just Like The Feeling
# 283          Air Supply  I Know You Better Than You Think
# 284          Air Supply                   I Remember Love
# 288          Air Supply                    If You Love Me
# 291          Air Supply      I'll Never Get Enough Of You
# 296          Air Supply                 It's Not Too Late
# 308          Air Supply                          Miracles
# ...                 ...                               ...
# 55823  Yngwie Malmsteen                          Ironclad
# 55826  Yngwie Malmsteen           Let The Good Times Roll
# 55836  Yngwie Malmsteen   See You In Hell (Don't Be Late)
# 55840  Yngwie Malmsteen                            Teaser
# 55849          Yo Gotti                               F-U
# 55856       Yo La Tengo               Speeding Motorcycle
# 55883          Yoko Ono     I Have A Woman Inside My Soul
# 55913     Yolanda Adams                         I Believe
# 55928          You Am I                            Get Up
# 55936          You Am I                         Pizza Guy
# 55937          You Am I                             Plans
# 55946          You Am I                             Sugar
# 55948          You Am I                           Tuesday
# 55953          You Am I          Who Put The Devil In You
# 55973         Young Dro                     It Ain't Over
# 56003       Young Jeezy                         Word Play
# 56007       Youngbloodz                             Damn!
# 56032              Z-Ro                         3Rd Coast
# 56039              Z-Ro           Don't Wanna Hurt Nobody
# 56040              Z-Ro                         Freestyle
# 56070    Zac Brown Band              Sic 'Em On A Chicken
# 56103             Zebra                  As I Said Before
# 56105             Zebra                       But No More
# 56109             Zebra                  Your Mind's Open
# 56117         Zebrahead      Be Careful What You Wish For
# 56119         Zebrahead                              Blur
# 56125         Zebrahead                     Here's To You
# 56126         Zebrahead                    Hit The Ground
# 56127         Zebrahead              House Is Not My Home
# 56143      Ziggy Marley                     Good Old Days
#
#                                                   lyrics
# 6      Down in the street they're all singing and sho...
# 31     So at last you're free  \r\r\r\r\r\r\r\r\r\r\r...
# 63     They say a restless body can hide a peaceful s...
# 73     Put on your white sombrero  \r\r\r\r\r\r\r\r\r...
# 92     Are you sure you want to hear more  \r\r\r\r\r...
# 122    I'm never gonna say I'm sorry,  \r\r\r\r\r\r\r...
# 135    Found myself today singing out your name,  \r\...
# 136    Daydreamer  \r\r\r\r\r\r\r\r\r\r\r\r\r\nSittin...
# 139    Right under my feet there's air made of bricks...
# 156    Ruby red... her lips were on fire  \r\r\r\r\r\...
# 163    It ain't easy, livin' like a gypsy.  \r\r\r\r\...
# 171    My girl, she breathes hellfire  \r\r\r\r\r\r\r...
# 177    Yeah, woke up one mornin'  \r\r\r\r\r\r\r\r\r\...
# 186    Rag doll, livin' in a movie  \r\r\r\r\r\r\r\r\...
# 194    If you believe in me  \r\r\r\r\r\r\r\r\r\r\r\r...
# 203    Goin' downtown, goin' down, goin' down  \r\r\r...
# 237    Night-  \r\r\r\r\r\r\r\r\r\r\r\r\r\nAnd the wo...
# 240    I'm lying alone with my head on the phone  \r\...
# 263    We shared such a special love, it seem to have...
# 264    Why do I say, don't walk away  \r\r\r\r\r\r\r\...
# 265    When you're out in front and your life is unsu...
# 268    Every night seems, dinner and wine  \r\r\r\r\r...
# 272    CLOSE YOUR EYES AND FILL THE SKIES  \r\r\r\r\r...
# 282    I just like the feeling  \r\r\r\r\r\r\r\r\r\r\...
# 283    (graham russell)  \r\r\r\r\r\r\r\r\r\r\r\r\r\n...
# 284    I've been staring at the floor  \r\r\r\r\r\r\r...
# 288    Stay with me only if your heart is free,  \r\r...
# 291    All last night we lay in bed making love  \r\r...
# 296    I stand alone I'm just a face in the crowd  \r...
# 308    I was thinking about miracles  \r\r\r\r\r\r\r\...
# ...                                                  ...
# 55823  I can't believe you're even trying this  \r\r\...
# 55826  I'm casting pearls before the swine.  \r\r\r\r...
# 55836  Can't bow for a rule  \r\r\r\r\r\r\r\r\r\r\nCa...
# 55840  Getting dressed for the masquerade  \r\r\r\r\r...
# 55849  Fuck you  \r\r\r\r\r\r\r\r\r\r\nFuck you  \r\r...
# 55856  Speeding motorcycle  \r\r\r\r\r\r\r\r\r\r\nWon...
# 55883  I have a woman inside my soul,  \r\r\r\r\r\r\r...
# 55913  They said you wouldn't make is so far uh uh  \...
# 55928  Got a kiss on the neck from a mornin' cartoon ...
# 55936  Grab a six pack for the way home.  \r\r\r\r\r\...
# 55937  Brush your hair to some Eurodisco trash  \r\r\...
# 55946  Sugar sit a while  \r\r\r\r\r\r\r\r\r\r\ncome ...
# 55948  Saw the sun come up again.  \r\r\r\r\r\r\r\r\r...
# 55953  I got too much on my mind  \r\r\r\r\r\r\r\r\r\...
# 55973  Extreme-aai  \r\r\r\r\r\r\r\r\r\r\nThis system...
# 56003  [Chorus]  \r\r\r\r\r\r\r\r\r\r\nYou niggas wan...
# 56007  OK, OK, OK  \r\r\r\r\r\r\r\r\r\r\nThis Sean Pa...
# 56032  Yeah, sup Ro, sup Grace, this your boy Den Den...
# 56039  You already know who it is nigga, 'King of Da ...
# 56040  Ha ha, 2000 and 1  \r\r\r\r\r\r\r\r\r\r\nZ-Ro ...
# 56070  [Chorus]  \r\r\r\r\r\r\r\r\r\r\nSic 'em on a c...
# 56103  And I said before  \r\r\r\r\r\r\r\r\r\r\nI don...
# 56105  The time is now or never  \r\r\r\r\r\r\r\r\r\r...
# 56109  You rest your mind  \r\r\r\r\r\r\r\r\r\r\nFlyi...
# 56117  This is me, I've got a nasty sense of humor  \...
# 56119  Did you ever get the feeling that you were all...
# 56125  Here she comes to ruin my day again  \r\r\r\r\...
# 56126  Anesthetized by these lies  \r\r\r\r\r\r\r\r\r...
# 56127  Well I'm tired, so tired of getting up and was...
# 56143  Irie days come on play  \r\r\r\r\r\r\r\r\r\r\n...
#
# [5621 rows x 3 columns]

# %% [markdown]
# One of the big differences between LDA and doc2vec approaches is that doc2vec allows us to choose our topics. LDA only allows the choice of number of topics.
